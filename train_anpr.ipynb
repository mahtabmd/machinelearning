# %% [markdown]
# <a href="https://colab.research.google.com/github/mahtabmd/machinelearning/blob/master/train_anpr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import files
files.upload()

# %%
ls -lh gdrive/MyDrive/realtime_anpr/kaggle.json
# Out:
# -rw------- 1 root root 70 Jun 10 19:07 gdrive/MyDrive/realtime_anpr/kaggle.json

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle #Create the directory

# %%
# !pwd ~
# Out:
# /content

# %%
# !cp gdrive/MyDrive/realtime_anpr/kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ref                                                                   title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# arnabchaki/data-science-salaries-2023                                 Data Science Salaries 2023 💸                         25KB  2023-04-13 09:55:16          29123        811  1.0
# tawfikelmetwally/automobile-dataset                                   Car information dataset                               6KB  2023-05-28 18:26:48           2623         72  0.9411765
# fatihb/coffee-quality-data-cqi                                        Coffee Quality Data (CQI May-2023)                   22KB  2023-05-12 13:06:39           5020        104  1.0
# ...

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/gdrive/MyDrive/realtime_anpr/input
# Out:
# /content/gdrive/MyDrive/realtime_anpr/input

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/realtime_anpr/input

# %%
# !kaggle datasets download -d elysian01/car-number-plate-detection
# Out:
# ...
# 100% 2.69G/2.69G [02:17<00:00, 21.8MB/s]
# 100% 2.69G/2.69G [02:17<00:00, 21.1MB/s]

# %%
# !ls  /content/gdrive/MyDrive/realtime_anpr/input
# Out:
# car-number-plate-detection.zip

# %%
# !unzip car-number-plate-detection.zip
# Out:
# Archive:  car-number-plate-detection.zip
#   inflating: Car_Number_Plate/00x500.jpg
#   inflating: Car_Number_Plate/1.jfif
#   inflating: Car_Number_Plate/1.png
#   inflating: Car_Number_Plate/10.jpg
#   inflating: Car_Number_Plate/10.png
#   inflating: Car_Number_Plate/11.jpg
#   inflating: Car_Number_Plate/11.png
#   inflating: Car_Number_Plate/1135560254.jpg
#   inflating: Car_Number_Plate/11793784.jpg
#   inflating: Car_Number_Plate/12.jpg
#   inflating: Car_Number_Plate/12.png
#   inflating: Car_Number_Plate/13.jpg
#   inflating: Car_Number_Plate/13.png
#   inflating: Car_Number_Plate/14.png
#   inflating: Car_Number_Plate/14.webp
#   inflating: Car_Number_Plate/15.jpg
#   inflating: Car_Number_Plate/15.png
#   inflating: Car_Number_Plate/16.png
#   inflating: Car_Number_Plate/17 (1).jpg
#   inflating: Car_Number_Plate/17.jpg
#   inflating: Car_Number_Plate/19.jpg
#   inflating: Car_Number_Plate/2.jfif
#   inflating: Car_Number_Plate/2.png
# ...

# %%
# %cd Car_Number_Plate/
# Out:
# /content/gdrive/MyDrive/realtime_anpr/input/Car_Number_Plate

# %% [markdown]
# input car number plate images 931 in nos downloaded from kaggle at location - /content/gdrive/MyDrive/realtime_anpr/input/Car_Number_Plate

# %%
# !ls  | wc -l
# Out:
# 931
